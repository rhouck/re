# %%
import pandas as pd

import settings
from utils import maps
# Out:
# /home/condauser/anaconda3/lib/python3.4/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
geos = pd.read_csv('data/geo/{0}.csv'.format(settings.TARGET_INDICATOR), converters={'code': str})
geos.head()
# Out:
#     code        lat         lon  \
# 0  00002  34.052234 -118.243685
# 1  00007  32.715738 -117.161084
# 2  00008  37.338208 -121.886329
# 3  00010  37.774929 -122.419415
# 4  00026  36.746842 -119.772587
#
#                                                 name      type
# 0  Los Angeles, Los Angeles County, California, U...  locality
# 1  San Diego, San Diego County, California, Unite...  locality
# 2  San Jose, Santa Clara County, California, Unit...  locality
# 3  San Francisco, San Francisco County, Californi...  locality
# 4   Fresno, Fresno County, California, United States  locality

# %%
m = maps.draw_CA()
style = dict(marker='o', alpha=0.3, zorder=2, latlon=True)
m.scatter(geos.lon.values, geos.lat.values, s=5, **style)
