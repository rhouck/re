# %%
from utils import quandl as ql
# Out:
# /home/condauser/anaconda3/lib/python3.4/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
ql.load_indicators()
# Out:
#                                 Indicator Name Indicator Code
# 0                                    All Homes              A
# 1                     Single Family Residences             SF
# 2                                 Condominiums              C
# 3                        Price per Square Foot           MVSF
# 4                                    1 Bedroom             1B
# 5                                    2 Bedroom             2B
# 6                                    3 Bedroom             3B
# 7                                    4 Bedroom             4B
# 8                                    5 or More             5B
# 9                                  Bottom Tier             BT
# 10                                 Middle Tier             MT
# 11                                    Top Tier             TT
# 12          Median Rent, Homes Listed for Rent            RMP
# 13         Estimated Rent, All Homes in Region            RAH
# ...

# %%
#for i in ('A','DV','IV','SLPR','SPY','SFG','LPC','5B','HR','MVSF','PRR','RZSF','RMP','RAH','FR',):
for i in ('MPC', 'MLPSF', 'MSPSF', 'TT', 'MT', 'BT', 'SFL', 'HF'):
    ql.scrape_quandl('cities', i)
# Out:
# this data set is already collected
# this data set is already collected
# this data set is already collected
# lets scrape cities / TT
# no data for code:	00002
# no data for code:	00007
# no data for code:	00008
# no data for code:	00010
# no data for code:	00026
# no data for code:	00028
# no data for code:	00029
# no data for code:	00037
# no data for code:	00040
# no data for code:	00042
# no data for code:	00044
# no data for code:	00047
# no data for code:	00053
# no data for code:	00056
# no data for code:	00068
# no data for code:	00069
# no data for code:	00076
# no data for code:	00080
# no data for code:	00087
# no data for code:	00088
# no data for code:	00089
# no data for code:	00098
# no data for code:	00101
# no data for code:	00107
# no data for code:	00108
# no data for code:	00109
# no data for code:	00114
# no data for code:	00116
# no data for code:	00122
# no data for code:	00126
# no data for code:	00127
# no data for code:	00131
# no data for code:	00132
# ...
